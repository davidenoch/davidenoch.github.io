# %%
import pandas as pd 
from IPython.display import display, HTML
df = pd.read_csv('Data/block_chain_info.csv')
def render_html_table(df):
    html_content = df.to_html(escape=False, index=False)
    display(HTML(html_content))
html_content = '''<div  > 
    <h3>Blockchain Reference Table</h3>
    Click on the logo for block explorer.
    <br>
    Click on the chain name for official website.
</div>
<br>'''

# %%
display(HTML(html_content))
render_html_table(df[['Logo', 'Chain link', 'Chain ID', 'Type', 'Color']])
# Out:
# <div style="max-width: 55ch;" >
#     <h3>Blockchain Reference Table</h3>
#     Click on the logo for block explorer.
#     <br>
#     Click on the chain name for official website.
# </div>
# <br>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Logo</th>
#       <th>Chain link</th>
#       <th>Chain ID</th>
#       <th>Type</th>
#       <th>Color</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><a href="https://explorer.aptoslabs.com"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/14803.png" alt="aptos" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://aptoslabs.com" style="color:#0B0B3B">aptos</a></td>
#       <td>NaN</td>
#       <td>L1</td>
#       <td>#0B0B3B</td>
#     </tr>
#     <tr>
#       <td><a href="https://arbiscan.io"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/11223.png" alt="arbitrum" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://arbitrum.io" style="color:#28A0F0">arbitrum</a></td>
#       <td>42161</td>
#       <td>EVM</td>
#       <td>#28A0F0</td>
#     </tr>
#     <tr>
#       <td><a href="https://aurorascan.dev"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/14803.png" alt="aurora" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://aurora.dev" style="color:#50D890">aurora</a></td>
#       <td>1313161554</td>
#       <td>EVM</td>
#       <td>#50D890</td>
#     </tr>
#     <tr>
#       <td><a href="https://snowtrace.io"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/12559.png" alt="avalanche" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://avax.network" style="color:#E84142">avalanche</a></td>
#       <td>43114</td>
#       <td>L1</td>
#       <td>#E84142</td>
#     </tr>
#     <tr>
#       <td><a href="https://axelarscan.io"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/15041.png" alt="axelar" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://axelar.network" style="color:#0B4C8C">axelar</a></td>
#       <td>1023</td>
#       <td>cosmos</td>
#       <td>#0B4C8C</td>
#     </tr>
#     <tr>
#       <td><a href="https://basescan.org"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/24488.png" alt="base" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://base.org" style="color:#0052FF">base</a></td>
#       <td>8453</td>
#       <td>EVM</td>
#       <td>#0052FF</td>
#     </tr>
#     <tr>
#       <td><a href="https://www.blockchain.com/explorer"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/1.png" alt="bitcoin" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://bitcoin.org" style="color:#F7931A">bitcoin</a></td>
#       <td>0</td>
#       <td>other</td>
#       <td>#F7931A</td>
#     </tr>
#     <tr>
#       <td><a href="https://explorer.blastapi.io"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/14746.png" alt="blast" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://blastapi.io" style="color:#6C757D">blast</a></td>
#       <td>147</td>
#       <td>EVM</td>
#       <td>#6C757D</td>
#     </tr>
#     <tr>
#       <td><a href="https://bscscan.com"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/1839.png" alt="bnb" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://www.binance.com" style="color:#F3BA2F">bnb</a></td>
#       <td>56</td>
#       <td>EVM</td>
#       <td>#F3BA2F</td>
#     </tr>
#     <tr>
#       <td><a href="https://bobascan.com"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/14556.png" alt="boba" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://boba.network" style="color:#B0BABF">boba</a></td>
#       <td>288</td>
#       <td>EVM</td>
#       <td>#B0BABF</td>
#     </tr>
#     <tr>
#       <td><a href="https://bscscan.com"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/1839.png" alt="bsc" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://www.binance.org/en/smartChain" style="color:#F0B90B">bsc</a></td>
#       <td>1</td>
#       <td>EVM</td>
#       <td>#F0B90B</td>
#     </tr>
#     <tr>
#       <td><a href="https://testnet.bscscan.com"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/1839.png" alt="bsc testnet" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://testnet.bscscan.com" style="color:#F0B90B">bsc testnet</a></td>
#       <td>97</td>
#       <td>EVM</td>
#       <td>#F0B90B</td>
#     </tr>
#     <tr>
#       <td><a href="https://explorer.celo.org"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/5567.png" alt="celo" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://celo.org" style="color:#FBCC5C">celo</a></td>
#       <td>42220</td>
#       <td>EVM</td>
#       <td>#FBCC5C</td>
#     </tr>
#     <tr>
#       <td><a href="https://www.mintscan.io/cosmos"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/3794.png" alt="cosmos" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://cosmos.network" style="color:#2E3148">cosmos</a></td>
#       <td>cosmoshub-4</td>
#       <td>cosmos</td>
#       <td>#2E3148</td>
#     </tr>
#     <tr>
#       <td><a href="https://cronos.org/explorer"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/3635.png" alt="cronos" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://cronos.org" style="color:#052169">cronos</a></td>
#       <td>25</td>
#       <td>EVM</td>
#       <td>#052169</td>
#     </tr>
#     <tr>
#       <td><a href="https://etherscan.io"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/1027.png" alt="ethereum" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://ethereum.org" style="color:#3C3C3D">ethereum</a></td>
#       <td>1</td>
#       <td>EVM</td>
#       <td>#3C3C3D</td>
#     </tr>
#     <tr>
#       <td><a href="https://flowscan.org"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/4558.png" alt="flow" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://www.onflow.org" style="color:#00EF8B">flow</a></td>
#       <td>flow-mainnet</td>
#       <td>L1</td>
#       <td>#00EF8B</td>
#     </tr>
#     <tr>
#       <td><a href="https://explorer.fuse.io"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/5634.png" alt="fuse" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://fuse.io" style="color:#46D7C7">fuse</a></td>
#       <td>122</td>
#       <td>EVM</td>
#       <td>#46D7C7</td>
#     </tr>
#     <tr>
#       <td><a href="https://gnosisscan.io"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/1659.png" alt="gnosis" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://gnosis.io" style="color:#048C8E">gnosis</a></td>
#       <td>100</td>
#       <td>EVM</td>
#       <td>#048C8E</td>
#     </tr>
#     <tr>
#       <td><a href="https://explorer.harmony.one"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/3945.png" alt="harmony" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://www.harmony.one" style="color:#00AEE9">harmony</a></td>
#       <td>1666600000</td>
#       <td>EVM</td>
#       <td>#00AEE9</td>
#     </tr>
#     <tr>
#       <td><a href="https://ftmscan.com"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/3513.png" alt="fantom" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://fantom.foundation" style="color:#1969FF">fantom</a></td>
#       <td>250</td>
#       <td>EVM</td>
#       <td>#1969FF</td>
#     </tr>
#     <tr>
#       <td><a href="https://lineascan.io"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/20172.png" alt="linea" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://linea.build" style="color:#62A8F3">linea</a></td>
#       <td>59144</td>
#       <td>EVM</td>
#       <td>#62A8F3</td>
#     </tr>
#     <tr>
#       <td><a href="https://mantleblockchain.io"><img src="https://s2.coinmarketcap.com/static/img/coins/64x64/16538.png" alt="mantle" style="width: 24px; height: 24px;"></a></td>
#       <td><a href="https://mantle.xyz" style="color:#42DFCD">mantle</a></td>
#       <td>5001</td>
#       <td>EVM</td>
#       <td>#42DFCD</td>
#     </tr>
#     <tr>
#       <td><a href="https://andromeda-explore

# %%
html_content = """ <div style="max-width: 55ch;">Hopefully, you can get some use out of this if you are researching or comparing multiple chains. You can use their logos, find out the explorer sites and official page as well as the chain id. The color is for charting to make it easier for viewers to follow which chain is which. Questions or suggestions? HMU on twitter or discord. I'm @potmo on both and am much more active on Discord than Twitter. 

-potmo
</div>



<div style=" margin-top: 20px;">
    <a href="https://twitter.com/potmo" target="_blank">
        <img src="https://cdn.iconscout.com/icon/free/png-256/twitter-241-721979.png" alt="Twitter" style="width: 24px; height: 24px;">
    </a>
    <a href="https://discord.gg/vxFsvUwEqg" target="_blank" style="margin-left: 10px;">
        <img src="https://cdn.iconscout.com/icon/free/png-256/discord-3-569463.png" alt="Discord" style="width: 24px; height: 24px;">
    </a>
    <a href="https://github.com/davidenoch/davidenoch.github.io/Blockchain-info" target="_blank" style="margin-left: 10px;">
        <img src="https://cdn.iconscout.com/icon/free/png-256/github-153-675523.png" alt="GitHub" style="width: 24px; height: 24px;">
    </a>
</div>
"""

# %%
display(HTML(html_content))
# Out:
#  <div style="max-width: 55ch;">Hopefully, you can get some use out of this if you are researching or comparing multiple chains. You can use their logos, find out the explorer sites and official page as well as the chain id. The color is for charting to make it easier for viewers to follow which chain is which. Questions or suggestions? HMU on twitter or discord. I'm @potmo on both and am much more active on Discord than Twitter.
#
# -potmo
# </div>
#
#
#
# <div style=" margin-top: 20px;">
#     <a href="https://twitter.com/potmo" target="_blank">
#         <img src="https://cdn.iconscout.com/icon/free/png-256/twitter-241-721979.png" alt="Twitter" style="width: 24px; height: 24px;">
#     </a>
#     <a href="https://discord.gg/vxFsvUwEqg" target="_blank" style="margin-left: 10px;">
#         <img src="https://cdn.iconscout.com/icon/free/png-256/discord-3-569463.png" alt="Discord" style="width: 24px; height: 24px;">
#     </a>
#     <a href="https://github.com/davidenoch/davidenoch.github.io/Blockchain-info" target="_blank" style="margin-left: 10px;">
#         <img src="https://cdn.iconscout.com/icon/free/png-256/github-153-675523.png" alt="GitHub" style="width: 24px; height: 24px;">
#     </a>
# </div>
